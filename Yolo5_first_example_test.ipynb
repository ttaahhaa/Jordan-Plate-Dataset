# %% [markdown]
# <a href="https://colab.research.google.com/github/ttaahhaa/Jordan-Plate-Dataset/blob/master/Yolo5_first_example_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !pip install -U -r yolov5/requirements.txt
# Out:
# Requirement already up-to-date: Cython in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 4)) (0.29.21)
# Requirement already up-to-date: matplotlib>=3.2.2 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 5)) (3.3.2)
# Requirement already up-to-date: numpy>=1.18.5 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 6)) (1.19.2)
# Requirement already up-to-date: opencv-python>=4.1.2 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 7)) (4.4.0.44)
# Requirement already up-to-date: pillow in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 8)) (7.2.0)
# Requirement already up-to-date: PyYAML>=5.3 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 9)) (5.3.1)
# Requirement already up-to-date: scipy>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 10)) (1.5.2)
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python detect.py --source inference/images/bus.jpg --weights yolov5l.pt --conf 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='inference/images/bus.jpg', update=False, view_img=False, weights=['yolov5l.pt'])
# Using CPU
#
# Fusing layers...
# Model Summary: 335 layers, 4.78187e+07 parameters, 0 gradients
# image 1/1 /content/yolov5/inference/images/bus.jpg: 640x512 4 persons, 1 buss, Done. (1.949s)
# Results saved to inference/output
# Done. (1.995s)

# %%
import torch
from IPython.display import Image, clear_output # to display images

Image(filename='inference/output/bus.jpg', width=600)
# Image(filename='inference/output/bus.jpg', width=600
